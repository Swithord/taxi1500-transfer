# %%
import pandas as pd
import os
from tqdm import tqdm

# %%
indices = []
data = {
    'classification': [],
    'text': [],
}
for file in ['eng_data/eng_train.tsv', 'eng_data/eng_dev.tsv', 'eng_data/eng_test.tsv']:
    with open(file, 'r') as f:
        for line in f:
            idx, classification, text = line.strip().split('\t')
            indices.append(idx)
            data['classification'].append(classification)
            data['text'].append(text)
df = pd.DataFrame(data, index=indices)

# %%
dir = 'Taxi1500-c_v3.0'
coverage = {
    'file': [],
    'annotated': [],
    'total': [],
    'proportion': [],
}
for file in tqdm(os.listdir(dir)):
    with open(os.path.join(dir, file), 'r') as f:
        indices = []
        data = {
            'classification': [],
            'text': [],
        }
        coverage['file'].append(file)
        annotated = 0
        total = 0
        for line in f:
            if line.startswith('#'):
                continue
            try:
                idx, text = line.strip().split('\t')
            except ValueError:
                continue
            total += 1
            if idx not in df.index:
                continue
            indices.append(idx)
            data['classification'].append(df.loc[idx]['classification'])
            data['text'].append(text)
            annotated += 1
        coverage['annotated'].append(annotated)
        coverage['total'].append(total)
        coverage['proportion'].append(annotated / total if total > 0 else 0)
        lang_df = pd.DataFrame(data, index=indices)
        lang_df.to_csv(f'processed_data/{file}.csv', index_label='id', encoding='utf-8-sig')
coverage_df = pd.DataFrame(coverage)
coverage_df.to_csv('coverage.csv', index=False, encoding='utf-8-sig')
coverage_df.set_index('file', inplace=True)
# Out:
# 100%|██████████| 1384/1384 [00:38<00:00, 36.34it/s]

# %%
high_resource_languages = ["eng", "spa", "deu", "jpn", "fra", "ara", "cmn"]

medium_resource_languages = ["ukr", "ceb", "arz", "lav", "ind", "afr", "bos", "glg", "ell", "heb", "bel", "zlm", "tha", "kat", "dan", "tgl", "slv", "tam", "kaz", "ron", "bul", "uzb", "lit", "est", "slk", "ben", "urd", "ltn", "swe", "tur", "kor", "hin", "fas", "por", "ces", "rus", "nld", "pol", "hrv", "ita", "vie", "eus", "hun", "fin", "srp", "cat"]

# %%
dir = 'processed_data'
files = {}
for i in range(len(coverage['file'])):
    file = coverage['file'][i]
    if len(file.split('_')) > 1:
        lang = file.split('_')[0]
    elif len(file.split('-')) > 1:
        lang = file.split('-')[0]
    else:
        continue
    if coverage['annotated'][i] < 900:
        continue
    if lang in files:
        files[lang].append(file)
    else:
        files[lang] = [file]
# Out:
# Not enough annotated data for bjp in file bjp_bjp.png.txt
# Not enough annotated data for ulk in file ulk_ulk.ebible.txt
# Not enough annotated data for dwu in file dwu_dwuliv.ebible.txt
# Not enough annotated data for eng in file eng_engwyc2018.ebible.txt
# Not enough annotated data for hvn in file hvn_hvn.ebible.txt
# Not enough annotated data for adz in file adz_adz.ebible.txt
# Not enough annotated data for aui in file aui-x-bible.txt
# Not enough annotated data for mgw in file mgw_mgw.ebible.txt
# Not enough annotated data for als in file als-x-bible.txt
# Not enough annotated data for uri in file uri_uri.ebible.txt
# Not enough annotated data for san in file san_sanori.ebible.txt
# Not enough annotated data for cha in file cha-x-bible-1908.txt
# Not enough annotated data for shj in file shj_shj.ebible.txt
# Not enough annotated data for mgh in file mgh_mgh.ebible.txt
# Not enough annotated data for eng in file eng_engoke.ebible.txt
# Not enough annotated data for eng in file eng_eng-Brenton.ebible.txt
# Not enough annotated data for gla in file gla-x-bible-apocrypha.txt
# Not enough annotated data for tuo in file tuo_tuoNT.ebible.txt
# Not enough annotated data for emi in file emi-x-bible.txt
# Not enough annotated data for soq in file soq_soq.ebible.txt
# Not enough annotated data for ksj in file ksj_ksj.ebible.txt
# Not enough annotated data for rmq in file rmq-x-bible-1837.txt
# Not enough annotated data for omw in file omw_omw-v.ebible.txt
# Not enough annotated data for rmc in file rmc_rmc.ebible.txt
# Not enough annotated data for kiw in file kiw_kiw.ebible.txt
# Not enough annotated data for lin in file lin_lin.ebible.txt
# Not enough annotated data for ipi in file ipi_ipi.ebible.txt
# Not enough annotated data for bea in file bea_bea.ebible.txt
# Not enough annotated data for tiw in file tiw_tiw.ebible.txt
# Not enough annotated data for mpp in file mpp_mpp.png.txt
# Not enough annotated data for gia in file gia_gia.ebible.txt
# Not enough annotated data for peg in file peg_peg.ebible.txt
# Not enough annotated data for kjn in file kjn_kjn.ebible.txt
# Not enough annotated data for pot in file pot-x-bible.txt
# Not enough annotated data for glk in file glk-x-bible.txt
# Not enough annotated data for aly in file aly_aly.ebible.txt
# Not enough annotated data for nbq in file nbq_nbq.ebible.txt
# Not enough annotated data for tew in file tew-x-bible.txt
# Not enough annotated data for msc in file msc_msc.ebible.txt
# Not enough annotated data for byr in file byr_byr-w.ebible.txt
# Not enough annotated data for san in file san_sansin.ebible.txt
# Not enough annotated data for wat in file wat_wat.ebible.txt
# Not enough annotated data for mpx in file mpx_mpx.ebible.txt
# Not enough annotated data for dhg in file dhg_dhg.ebible.txt
# Not enough annotated data for hbo in file hbo_hbo.ebible.txt
# Not enough annotated data for kca in file kca_kca.ebible.txt
# Not enough annotated data for wbp in file wbp_wbp.ebible.txt
# Not enough annotated data for mwc in file mwc_mwc.ebible.txt
# Not enough annotated data for tte in file tte_tteo.ebible.txt
# Not enough annotated data for cha in file cha_cha.ebible.txt
# Not enough annotated data for tbl in file tbl_tblNT.ebible.txt
# Not enough annotated data for thd in file thd_thd.ebible.txt
# Not enough annotated data for tgk in file tgk_tgk.ebible.txt
# Not enough annotated data for tbg in file tbg_tbg-a.ebible.txt
# Not enough annotated data for kqw in file kqw_kqw.ebible.txt
# Not enough annotated data for eng in file eng_englee.ebible.txt
# Not enough annotated data for gup in file gup_gupmay.ebible.txt
# Not enough annotated data for tkr in file tkr_tkr.ebible.txt
# Not enough annotated data for dwy in file dwy_dwy.ebible.txt
# Not enough annotated data for san in file san_santel.ebible.txt
# Not enough annotated data for cop in file cop_copbhc.ebible.txt
# Not enough annotated data for spm in file spm_spm.ebible.txt
# Not enough annotated data for san in file san_saniso.ebible.txt
# Not enough annotated data for tnc in file tnc_tnc.ebible.txt
# Not enough annotated data for mpj in file mpj_mpj.ebible.txt
# Not enough annotated data for bxh in file bxh_bxh.ebible.txt
# Not enough annotated data for hbo in file hbo_hboWLC.ebible.txt
# Not enough annotated data for iou in file iou_iou.ebible.txt
# Not enough annotated data for tpa in file tpa_tpa.ebible.txt
# Not enough annotated data for awx in file awx_awx.ebible.txt
# Not enough annotated data for bla in file bla_bla.ebible.txt
# Not enough annotated data for wrk in file wrk_wrk.ebible.txt
# Not enough annotated data for nif in file nif_nif.ebible.txt
# Not enough annotated data for lit in file lit_lit.ebible.txt
# Not enough annotated data for san in file san_sanitr.ebible.txt
# Not enough annotated data for kkc in file kkc_kkc.png.txt
# Not enough annotated data for san in file san_sandev.ebible.txt
# Not enough annotated data for wal in file wal_wal.ebible.txt
# Not enough annotated data for eng in file eng_engWycliffe.ebible.txt
# Not enough annotated data for enq in file enq_enq2.png.txt
# Not enough annotated data for rmy in file rmy_rmyChergash.ebible.txt
# Not enough annotated data for djj in file djj_djj.ebible.txt
# Not enough annotated data for pma in file pma_pma.ebible.txt
# Not enough annotated data for eng in file eng_engwyc2017.ebible.txt
# Not enough annotated data for bco in file bco_bco.png.txt
# Not enough annotated data for lrg in file lrg_lrg.ebible.txt
# Not enough annotated data for eng in file eng_engjps.ebible.txt
# Not enough annotated data for kux in file kux_kux.ebible.txt
# Not enough annotated data for bsp in file bsp_bsp.ebible.txt
# Not enough annotated data for amx in file amx_amx.ebible.txt
# Not enough annotated data for cpy in file cpy_cpy.ebible.txt
# Not enough annotated data for rmn in file rmn_rmn.ebible.txt
# Not enough annotated data for eng in file eng_eng-uk-lxx2012.ebible.txt
# Not enough annotated data for wed in file wed_wed.ebible.txt
# Not enough annotated data for san in file san_santam.ebible.txt
# Not enough annotated data for bkx in file bkx_bkx.ebible.txt
# Not enough annotated data for nce in file nce_nce.ebible.txt
# Not enough annotated data for nss in file nss_nss.ebible.txt
# Not enough annotated data for hau in file hau_hausa.ebible.txt
# Not enough annotated data for dak in file dak-x-bible.txt
# Not enough annotated data for san in file san_sankhm.ebible.txt
# Not enough annotated data for san in file san_sanhk.ebible.txt
# Not enough annotated data for eko in file eko-x-bible.txt
# Not enough annotated data for mph in file mph_mph.ebible.txt
# Not enough annotated data for tke in file tke_tke.ebible.txt
# Not enough annotated data for etr in file etr_etr.ebible.txt
# Not enough annotated data for snx in file snx_snx.ebible.txt
# Not enough annotated data for klt in file klt_klt.ebible.txt
# Not enough annotated data for eng in file eng_eng-lxx2012.ebible.txt
# Not enough annotated data for rmy in file rmy_rmylovari.ebible.txt
# Not enough annotated data for eng in file eng_engourb.ebible.txt
# Not enough annotated data for xbi in file xbi_xbi-w.ebible.txt
# Not enough annotated data for seh in file seh_seh.ebible.txt
# Not enough annotated data for bre in file bre_breBRG.ebible.txt
# Not enough annotated data for wro in file wro_wro.ebible.txt
# Not enough annotated data for kkc in file kkc_kkc.ebible.txt
# Not enough annotated data for bmk in file bmk_bmk.ebible.txt
# Not enough annotated data for glv in file glv-x-bible-apogryphs.txt
# Not enough annotated data for nss in file nss-x-bible.txt
# Not enough annotated data for jao in file jao_jao.ebible.txt
# Not enough annotated data for xbi in file xbi_xbi-y.ebible.txt
# Not enough annotated data for aui in file aui_aui.ebible.txt
# Not enough annotated data for rmb in file rmb_rmb.ebible.txt
# Not enough annotated data for arb in file arb_arbnav.ebible.txt
# Not enough annotated data for beu in file beu_beu.ebible.txt
# Not enough annotated data for tew in file tew_tew.ebible.txt
# Not enough annotated data for fue in file fue_fue.ebible.txt
# Not enough annotated data for urw in file urw_urw.ebible.txt
# Not enough annotated data for san in file san_sanguj.ebible.txt
# Not enough annotated data for san in file san_sankan.ebible.txt
# Not enough annotated data for san in file san_sanasm.ebible.txt
# Not enough annotated data for mzz in file mzz_mzz.ebible.txt
# Not enough annotated data for omw in file omw_omw-a.ebible.txt
# Not enough annotated data for san in file san_sanpun.ebible.txt
# Not enough annotated data for kqa in file kqa_kqa.ebible.txt
# Not enough annotated data for san in file san_sanias.ebible.txt
# Not enough annotated data for lbb in file lbb_lbb.png.txt
# Not enough annotated data for wlg in file wlg_wlg.ebible.txt
# Not enough annotated data for juy in file juy_juy.ebible.txt
# Not enough annotated data for eng in file eng_engaoi.ebible.txt
# Not enough annotated data for san in file san_santib.ebible.txt
# Not enough annotated data for mgc in file mgc_mgc.ebible.txt
# Not enough annotated data for eng in file eng_engnna.ebible.txt
# Not enough annotated data for aln in file aln-x-bible-psalter.txt
# Not enough annotated data for eng in file eng_englxxup.ebible.txt
# Not enough annotated data for bpx in file bpx_bpx.ebible.txt
# Not enough annotated data for wed in file wed_wed-topura.ebible.txt
# Not enough annotated data for bhg in file bhg_bhg.ebible.txt
# Not enough annotated data for rmy in file rmy_rmyGurbet.ebible.txt
# Not enough annotated data for adz in file adz_adz.png.txt
# Not enough annotated data for arp in file arp_arp.ebible.txt
# Not enough annotated data for pma in file pma-x-bible.txt
# Not enough annotated data for ekk in file ekk_ekkpkp.ebible.txt
# Not enough annotated data for kqw in file kqw_kqw.png.txt
# Not enough annotated data for grc in file grc_grcbrent.ebible.txt
# Not enough annotated data for rmy in file rmy_rmyvlakh.ebible.txt
# Not enough annotated data for san in file san_sanvel.ebible.txt
# Not enough annotated data for san in file san_sancol.ebible.txt
# Not enough annotated data for rmy in file rmy_rmyservi.ebible.txt
# Not enough annotated data for arb in file arb_arb-vd.ebible.txt
# Not enough annotated data for cop in file cop_copcnt.ebible.txt
# Not enough annotated data for san in file san_sanben.ebible.txt
# Not enough annotated data for gup in file gup_gupk.ebible.txt
# Not enough annotated data for aoi in file aoi_aoi.ebible.txt
# Not enough annotated data for rmn in file rmn-x-bible-1912.txt
# Not enough annotated data for nyu in file nyu-x-bible.txt
# Not enough annotated data for rup in file rup-x-bible-1889.txt
# Not enough annotated data for awk in file awk_awk.ebible.txt
# Not enough annotated data for ktm in file ktm_ktm.ebible.txt
# Not enough annotated data for tvk in file tvk-x-bible-ebible.txt
# Not enough annotated data for eko in file eko_eko.ebible.txt
# Not enough annotated data for ahr in file ahr_ahr.ebible.txt
# Not enough annotated data for gvn in file gvn_gvn.ebible.txt
# Not enough annotated data for rmq in file rmq-x-bible-1872.txt
# Not enough annotated data for kos in file kos-x-bible.txt
# Not enough annotated data for mkj in file mkj_mkj.ebible.txt
# Not enough annotated data for wmt in file wmt_wmt.ebible.txt
# Not enough annotated data for san in file san_sanbur.ebible.txt
# Not enough annotated data for kkl in file kkl_kkl.ebible.txt
# Not enough annotated data for fra in file fra_frasbl.ebible.txt
# Not enough annotated data for ron in file ron_ronBayash.ebible.txt
# Not enough annotated data for kky in file kky_kky.ebible.txt
# Not enough annotated data for gaq in file gaq_gaq.ebible.txt
# Not enough annotated data for san in file san_santha.ebible.txt
# Not enough annotated data for mwp in file mwp_mwp.ebible.txt
# Not enough annotated data for glk in file glk_glk.ebible.txt
# Not enough annotated data for sbe in file sbe_sbe.ebible.txt
# Not enough annotated data for deu in file deu-x-bible-reinhardt1910.txt
# Not enough annotated data for nrf in file nrf-x-bible.txt
# Not enough annotated data for mwf in file mwf_mwf2018.ebible.txt
# Not enough annotated data for kqc in file kqc-x-bible.txt
# Not enough annotated data for wol in file wol_wolKYG.ebible.txt
# Not enough annotated data for adt in file adt_adt.ebible.txt
# Not enough annotated data for dop in file dop_dop.ebible.txt
# Not enough annotated data for nay in file nay_nay.ebible.txt
# Not enough annotated data for got in file got-x-bible.txt
# Not enough annotated data for sbe in file sbe_sbe.png.txt
# Not enough annotated data for ron in file ron_ronludari.ebible.txt
# Not enough annotated data for kqf in file kqf-x-bible.txt
# Not enough annotated data for nmw in file nmw_nmws.ebible.txt
# Not enough annotated data for als in file als-x-bible-psalter.txt
# Not enough annotated data for xbi in file xbi-x-bible-yanimoi.txt
# Not enough annotated data for kql in file kql_kql.ebible.txt
# Not enough annotated data for rmy in file rmy_rmyArli.ebible.txt
# Not enough annotated data for san in file san_sanurd.ebible.txt
# Not enough annotated data for gue in file gue_gue.ebible.txt
# Not enough annotated data for anh in file anh_anh.ebible.txt
# Not enough annotated data for nys in file nys_nys.ebible.txt
# Not enough annotated data for moh in file moh-x-bible.txt
# Not enough annotated data for nna in file nna_nna.ebible.txt
# Not enough annotated data for kxv in file kxv_kxv.ebible.txt
# Not enough annotated data for etr in file etr_etr.png.txt
# Not enough annotated data for san in file san_sanmal.ebible.txt
# Not enough annotated data for ulk in file ulk_ulk1902.ebible.txt
# Not enough annotated data for yij in file yij_yij.ebible.txt
# Not enough annotated data for dhg in file dhg_dhgduwadha.ebible.txt
# Not enough annotated data for tod in file tod_tod.ebible.txt
# Not enough annotated data for unx in file unx_unx.ebible.txt
# Not enough annotated data for dso in file dso_dso.ebible.txt
# Not enough annotated data for pes in file pes_pesOPV.ebible.txt
# Not enough annotated data for omb in file omb_omb.ebible.txt
# Not enough annotated data for kqf in file kqf_kqf.ebible.txt
# Not enough annotated data for mbb in file mbb_mbbOT.ebible.txt
# Not enough annotated data for rmc in file rmc_rmczrb.ebible.txt
# Not enough annotated data for wed in file wed-x-bible-wedau.txt
# Not enough annotated data for dji in file dji_dji.ebible.txt
# Not enough annotated data for eng in file eng_eng-glw.ebible.txt
# Not enough annotated data for eng in file eng_engPEV.ebible.txt

# %%
transfer_langs = []
for lang in high_resource_languages + medium_resource_languages:
    if lang not in files:
        print(f'No files for language: {lang}')
        continue
    transfer_langs.append(lang)
print(transfer_langs)
# Out:
# No files for language: ara
# No files for language: lav
# No files for language: afr
# No files for language: bos
# No files for language: glg
# No files for language: ell
# No files for language: bel
# No files for language: kat
# No files for language: slv
# No files for language: kaz
# No files for language: bul
# No files for language: uzb
# No files for language: lit
# No files for language: est
# No files for language: slk
# No files for language: ltn
# No files for language: tur
# No files for language: kor
# No files for language: fas
# No files for language: cat
# ['eng', 'spa', 'deu', 'jpn', 'fra', 'cmn', 'ukr', 'ceb', 'arz', 'ind', 'heb', 'zlm', 'tha', 'dan', 'tgl', 'tam', 'ron', 'ben', 'urd', 'swe', 'hin', 'por', 'ces', 'rus', 'nld', 'pol', 'hrv', 'ita', 'vie', 'eus', 'hun', 'fin', 'srp']

# %%
train = []
with open('eng_data/eng_train.tsv', 'r') as f:
    for line in f:
        idx, classification, text = line.strip().split('\t')
        train.append(int(idx))
dev = []
with open('eng_data/eng_dev.tsv', 'r') as f:
    for line in f:
        idx, classification, text = line.strip().split('\t')
        dev.append(int(idx))
test = []
with open('eng_data/eng_test.tsv', 'r') as f:
    for line in f:
        idx, classification, text = line.strip().split('\t')
        test.append(int(idx))

# %%
for lang in tqdm(files):
    best_coverage = 0
    best_filename = None
    for file in files[lang]:
        if coverage_df.loc[file]['annotated'] > best_coverage:
            best_coverage = coverage_df.loc[file]['annotated']
            best_filename = file
    assert(best_filename is not None)
    lang_train, lang_dev, lang_test = [], [], []
    lang_df = pd.read_csv(os.path.join('processed_data', best_filename + '.csv'), index_col='id')
    for idx in lang_df.index:
        if idx in train:
            lang_train.append((idx, lang_df.loc[idx]['classification'], lang_df.loc[idx]['text']))
        elif idx in dev:
            lang_dev.append((idx, lang_df.loc[idx]['classification'], lang_df.loc[idx]['text']))
        elif idx in test:
            lang_test.append((idx, lang_df.loc[idx]['classification'], lang_df.loc[idx]['text']))
    lang_train_df = pd.DataFrame(lang_train, columns=['id', 'classification', 'text'])
    lang_dev_df = pd.DataFrame(lang_dev, columns=['id', 'classification', 'text'])
    lang_test_df = pd.DataFrame(lang_test, columns=['id', 'classification', 'text'])
    lang_train_df.to_csv(f'final_data/{lang}_train.csv', index=False, encoding='utf-8-sig')
    lang_dev_df.to_csv(f'final_data/{lang}_dev.csv', index=False, encoding='utf-8-sig')
    lang_test_df.to_csv(f'final_data/{lang}_test.csv', index=False, encoding='utf-8-sig')
# Out:
# 100%|██████████| 804/804 [00:23<00:00, 33.79it/s]
